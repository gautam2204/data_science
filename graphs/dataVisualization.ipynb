# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import numpy as np
import os

# %%
# %matplotlib inline

# %%
csvFilePath = "\\clean_df_forGraph.csv"
print(csvFilePath)
df = pd.read_csv(os.curdir+csvFilePath,index_col=0)
brand_cityAvg =df[['wheel-base','city-mpg']].head(10)

pt=plt.plot(range(0,10),brand_cityAvg['city-mpg'])
# Out:
# \clean_df_forGraph.csv

# %%
brand_cityAvg =df[['stroke','city-L/100km']]
plt.scatter(brand_cityAvg['stroke'],brand_cityAvg['city-L/100km'])

# %%
brand_cityAvg =df[['engine-size','price']].round()
sns.regplot(x='engine-size',y='price',data=brand_cityAvg)
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
brand_cityAvg =df[['bore','stroke']].round()
sns.regplot(x='bore',y='stroke',data=brand_cityAvg)
# Out:
# <Axes: xlabel='bore', ylabel='stroke'>
