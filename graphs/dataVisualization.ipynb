# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import numpy as np

# %%
# %matplotlib inline

# %%
df = pd.read_csv("D:\Git Project\Cousera\data_science\DataWrangling\clean_df.csv",index_col=0)
brand_cityAvg =df[['wheel-base','city-mpg']].head(10)

pt=plt.plot(brand_cityAvg['city-mpg'],brand_cityAvg['wheel-base'])
pt.xlabel("Mileage")
pt.ylabel("Wheel Base")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 5
#       2 brand_cityAvg =df[['wheel-base','city-mpg']].head(10)
#       4 pt=plt.plot(brand_cityAvg['city-mpg'],brand_cityAvg['wheel-base'])
# ----> 5 pt.xlabel("Mileage")
#       6 pt.ylabel("Wheel Base")
#
# AttributeError: 'list' object has no attribute 'xlabel'
