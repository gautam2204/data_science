# %%
import pandas as pd

# %%
val = range(0,10)
val
# Out:
# range(0, 10)

# %%
expected_features = ['tag', 'href', 'role', 'type', 'name', 'button-type', 'mat-button',
       'target', 'disabled', 'onclick', 'label', 'clickable']

# %%
df = pd.read_json('domData.json')
# drop intial rows not needed like head script 
# df.drop(range(0,561),inplace=True)
# df.reset_index(inplace=True)
#Move hasClickEvent to end and rename it as clickable
moveToLast=df['hasClickEvent']
df.drop(labels=['hasClickEvent'], axis=1,inplace = True)
df.insert(len(df.columns.to_list()), 'clickable', moveToLast)
#remove unwanted tag values
df=df[~df['tag'].isin(['symbol', 'path','defs'])]
df.reset_index(drop=True,inplace=True)
df.head()
# Out:
#       tag                                               text  tabindex  \
# 0  IFRAME                                                         -1.0
# 1     DIV                                                          NaN
# 2     svg                                                          NaN
# 3  HEADER  document.querySelector('body').classList.add("...       NaN
# 4     DIV  document.querySelector('body').classList.add("...       NaN
#
#                 id                  class data-gcb-service-node  \
# 0  coBrowseUIFrame         __cbio_ignored                  true
# 1              NaN        qui-icon-sprite                   NaN
# 2              NaN                    NaN                   NaN
# 3              NaN  navbar navbar-default                   NaN
# 4              NaN        container-fluid                   NaN
#
#                                                style  \
# 0  box-sizing: border-box; width: 0px; height: 0p...
# ...

# %%
# df.drop(columns=['text','class','data-gcb-service-node','style','svg-src','version',
#                  'clip-rule','xmlns','xmlns:xlink','d','fill-rule',
#                  'text','vertical','alt-mode-src','style','ng-version','aria-label',
#                  'interactive','qui-aria-label','xmlns:xlink','d','fill-rule',
#                  'viewBox','class','data-gcb-service-node','style','svg-src','version',
#                  'clip-rule','xmlns','xmlns:xlink','d','fill-rule',
#                  'text','_nghost-ng-c1293260640','_ngcontent-ng-c1293260640','aria-orientation','rel','defer',
#                  'language','action','is','validate','fill-rule'],inplace=True)
df.describe(include='all')
# Out:
#          tag  text   tabindex   id                             class  \
# count   2393  2393  14.000000  218                              1645
# unique    44   429        NaN  132                               333
# top      DIV              NaN       link standalone ng-star-inserted
# freq     510   649        NaN   62                               151
# mean     NaN   NaN  -0.357143  NaN                               NaN
# std      NaN   NaN   0.497245  NaN                               NaN
# min      NaN   NaN  -1.000000  NaN                               NaN
# 25%      NaN   NaN  -1.000000  NaN                               NaN
# 50%      NaN   NaN   0.000000  NaN                               NaN
# 75%      NaN   NaN   0.000000  NaN                               NaN
# max      NaN   NaN   0.000000  NaN                               NaN
#
#        data-gcb-service-node           style  \
# count                      2              51
# ...

# %%
# result = df.loc[df['clickable']==True]
# result = result.dropna(axis=1, how='all')
# result.describe(include='all')

# %%
# result.drop(columns=['text','class','aria-label','qui-aria-label','ng-version','color','fieldcontrol',
#                  'value','maxlength','minlength','text-align','appearance',
#                  'visibility','aria-checked','aria-describedby','mat-ripple-loader-uninitialized','mat-ripple-loader-class-name',
#                  'mat-ripple-loader-disabled','data-analytics-linkname','data-attr-primarynav-name','data-attribute-navid',
#                  'aria-live','data-datasource','tabindex','id','size','aria-disabled','icon-position',
#                  'cta-appearance','variant','cta-type','icon-name','icon-size','aria-expanded',
#                  'data-subnav'],inplace=True)
# result

# %%
# result.columns

# %%
df = df[expected_features]
df.describe(include='all')
# Out:
#          tag     href role             type name button-type mat-button  \
# count   2393      659  155               95   14           4         53
# unique    44      147   14                8    8           2          3
# top      DIV  #launch  img  text/javascript    q      button      false
# freq     510       41   89               73    4           3         25
#
#        target disabled                                        onclick  \
# count     539       11                                              1
# unique      2        1                                              1
# top     _self    false  location.href='/public/authentication/enroll'
# freq      410       11                                              1
#
#                                  label clickable
# count                                2      2393
# unique                               1         2
# top     Enter city, state, or ZIP code     False
# freq                                 2      2047

# %%
X =
# Out:
#   Cell In[177], line 1
#     X =
#         ^
# SyntaxError: invalid syntax
